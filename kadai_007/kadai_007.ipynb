# %%
#「array」という名前のリストを作成
weather_names = ["月曜日は晴れです", "火曜日は雨です", "水曜日は晴れです", "木曜日は晴れです", "金曜日は曇りです", "金曜日は曇りです", "金曜日は曇りです"]

#水曜日を取り出す
print(weather_names[2])
# Out:
# 水曜日は晴れです

# %%
#「dictionary」という名前のディクショナリ
dictionary = {"mon": "晴れ", "tue": "雨", "wed": "晴れ", "thu": "晴れ", "fri": "曇り", "sat": "曇りのち雨", "sun":"雷雨"}
#水曜日を取り出す
print(dictionary["wed"])
# Out:
# 晴れ
